# %% [markdown]
# # Lecture 1 - Python 語法介紹(I)

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-08%20%E4%B8%8A%E5%8D%881.52.03.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-08%20%E4%B8%8A%E5%8D%881.52.03.png)

# %% [markdown]
# 康妮圖的Source: <https://forum.gamer.com.tw/C.php?page=1&bsn=60076&snA=4015045&subbsn=0> (**警告: 上課不要偷看!** )
#
# -------
#
# ## 介紹環境
#
# 目前你們在的環境是 **Jupyter notebook**, 前身為 iPython notebook,
#
# 在這裡主要透過筆記的方式來教導大家一些 Python 的語法.
#
# Jupyter 其中之一的特點為: 可以在上面撰寫你的程式碼,
#
# 通常這些程式碼比較偏向是測試用, 這種調性挺適合我們介紹 Python 給大家.
#
# 而在這個 Jupyter notebook 中則以一個一個 Cell 窗格組合而成,
#
# 本窗格為 **markdown** 格式, 通常拿來寫成筆記文件用.
#
# 如果你有興趣了解 markdown 長怎樣, 不訪點兩下這個窗格, 便可以看到原始 markdown 的面貌,
#
# 按下上方的 Run 後, 就可以恢復原本漂亮的樣子.
#
# 詳細 markdown 語法可參考 <http://markdown.tw>

# %% [markdown]
# ## Hello world
#
# 大家記得我們在 C 中**最初的感動**是什麼嗎?
#
# 沒錯, 就是那行 Hello world
#
# 打了數行的程式碼, 最終在黑框框列印出了一段字 `Hello world.`
#
# > Hello world
# ```C
# #include <stdio.h>
# int main(void) {
#   printf("Hello world.\n");
#   return(0);
# }
# ```
#
# 而在 Python 中, 要印出**最初的感動**其實很簡單
#
# 就是以下一行程式碼而已

# %%
print("Hello world.")
# Out:
# Hello world.

# %% [markdown]
# ## 差別待遇
#
# 令人好奇的是, 究竟為何 Python 只需短短一行程式碼便可以讓我們尋找到最初的感動呢
#
# 因為 Python 是**直譯式程式語言**, 相較於 C 的**編譯式程式語言**特性
#
# 直譯式語言 Python 會隨著你提供的程式碼傻傻的一行一行執行下來, 直到出錯才停止
#
# 而編譯式語言的 C 則需要透過編譯器全盤式地檢查**語法**都無錯誤後才會讓你執行程式
#
# 由於因為編譯式語言能夠將程式碼轉為二進制語言, 在電腦上執行速度通常會比直譯式來的快
#
# 雖然直譯式語言提供了方便性, 不代表效能注定永遠跟不上編譯式的語言, Python 也是可以做編譯成二進制語言的.

# %% [markdown]
# ### 還記得多少個夜晚與 Dev-C++ 奮鬥, 擠破頭也看不出來錯在哪, 這都怪我們太過年輕, 太衝動, 不知埋了多少 Bug 在其中

# %% [markdown]
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-08%20%E4%B8%8A%E5%8D%882.20.36.png](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202018-03-08%20%E4%B8%8A%E5%8D%882.20.36.png)

# %% [markdown]
# ### 如今在 Python 中, 錯了就直接告訴你哪裡錯, 絕不拐彎抹角, 好誠實, 好港動 (｡◕∀◕｡)
#
# * 原來是忘記宣告變數 `my_name`

# %%
print("Is this okay?")
print("If I want to print my name %s?" % ("Bowen"))
print("What if I want to print my name %s in variable?" % (my_name))
# Out:
# Is this okay?
# If I want to print my name Bowen?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3e8551ea4629> in <module>()
#       1 print("Is this okay?")
#       2 print("If I want to print my name %s?" % ("Bowen"))
# ----> 3 print("What if I want to print my name %s in variable?" % (my_name))
#
# NameError: name 'my_name' is not defined

# %% [markdown]
# ## 正課開始
#
# ### Outline
#
# * [常數 Constants](#constants)
# * [變數 Variables](#variables)
#   * [變數命名規則 Variable name rules](#variable_name_ruels)
#   * [保留字 Resercved words](#reserved_words)
# * [Sentences or Lines](#sentences_or_lines)
# * [賦值敘述句 Assignment statements](#assignment_statements)
# * [數值表達 Numeric expressions](#numeric_expressions)
#   * [計算順序 Order of evaluation](#order_of_evaluation)
#   * [整數與浮點數混雜 Mixing integer and floating](#mixing_integer_and_floating)
# * [型別 Type](#type)
# * [使用者輸入 User input](#user_input)
# * [註解 Comments](#comments)
# * [字串運算 String operations](#string_operations)
# * [變數名稱 Variable names](#variable_names)

# %% [markdown]
# <a href="constants"></a>
# ### 常數 Constants
#
# 常數為一個固定的值, 例如一個數字, 字元或是字串. 因為它的值無法做改變, 所以我們都稱它為常數.
#
# 可分為二類:
#
# 1. 數值常數,
#
# 2. 字串常數
# 	* 字串常數被單引號(`'`)或是雙引號(`"`)包圍

# %%
print(123)  # numeric constant
print(9.83) # numeric constant
print('Hello world') # string constant
print("Hello world") # string constant
# Out:
# 123
# 9.83
# Hello world
# Hello world

# %% [markdown]
# <a href="variables"></a>
# ### 變數 Variables
#
# 通常程式設計師會需要一個記憶體空間來存取資料, 為了方便存取那個記憶體空間, 我們會將它取一個名字.
#
# 而這個記憶體空間就是這小節的主角: **變數**
#
# 而在一個變數中, 我們可以隨意更改它記憶體空間中的值

# %%
x = 12.2
y = 14
x = 100
y = "15y"
print(x, y)
# Out:
# 100 15y

# %% [markdown]
# <a href="variable_name_rules"></a>
# ### 變數命名規則 Variable name rules
#
# 1. 變數的名字必須從字母(letter)或是底線(underscore `_`)開始
#
# 2. 只能包含字母, 數字跟底線
#
# 3. 大小寫有別
#
# 4. Example
#
#     ```python
# 	spam eggs spam123 _speed # Good variable names
#     23spam #sign var.12 # Bad
#     spam Spam SPAM # Different
#     ```

# %% [markdown]
# <a href="reserved_words"></a>
# ### 保留字 Reserved words
#
# Python 中有一些保留字, 你不能用這些保留字當作你變數的名字
#
# ```python
# and del for is raise assert elif
# from lambda return break else
# global not try class except if
# or while continue exec import
# pass yield def finally in print as with
# ```

# %% [markdown]
# <a href="sentences_or_lines"></a>
# ### Sentences or lines
#
# ```python
# x = 2        # 賦值敘述 Assignment statement
# x = x + 2    # 賦值敘述 ft.表達句 Assignment with expression
# print(x)     # 輸出敘述 Print statement
#
# # Variable: x
# # Operator: +
# # Constant: 2
# # Reserved word: print
# ```

# %% [markdown]
# <a href="assignment_statements"></a>
# ### 賦值敘述句 Assignment statements
#
# 當我們想要指定一個值給一個變數時, 我們會用賦值敘述句 (`=`)
#
# 在 `=` 的右邊放上表達式 expression, `=` 左邊放上變數 variable
#
# `variable = expression`
#
# 當右側的 expression 被計算完後, 會把結果 assign 給左邊的變數

# %%
x = 0.6
x = 3.9 * x * (1-x)
print(x)
# Out:
# 0.9359999999999999

# %% [markdown]
# <a href="numeric_expressions"></a>
# ### 數值表達 Numeric expressions
#
# | 運算子 | 動作 |
# | ----- | ---- |
# | + | 加 |
# | - | 減 |
# | * | 乘 |
# | / | 除 |
# | **| n次方 |
# | % | 餘 |

# %%
xx = 2
xx = xx + 2
print(xx)

yy = 440 * 12
print(yy)

zz = yy / 1000
print(zz)

jj = 23
kk = jj % 5
print(kk)

print(4**3)
# Out:
# 4
# 5280
# 5.28
# 3
# 64

# %% [markdown]
# <a href="order_of_evaluation"></a>
# ### 計算順序 Order of evaluation
#
# 順序性為
#
# 1. 括號 Parenthesis
# 2. 指數 Exponentiation (power)
# 3. 乘, 除, 餘
# 4. 加, 減
# 5. 由左至右

# %%
x = 1 + 2 ** 3 / 4 * 5
print(x)
# Out:
# 11.0

# %% [markdown]
# <a href="mixing_integer_and_floating"></a>
# ### 整數與浮點數混雜 Mixing integer and floating
#
# 當整數 integer 與浮點數 floating 混雜計算時, 整數會被轉為浮點數來作運算

# %%
print(99/100.0)
print(2 * 3)
print(2 * 3.3)
print(1 + 2 * 3 / 4.0 - 5 - 2.5)
# Out:
# 0.99
# 6
# 6.6
# -5.0

# %% [markdown]
# <a href="type"></a>
# ### 型別 Type
#
# 在 Python 中, 變數都有各自的型別 type.
#
# 因為 Python 是高階語言, 所以它會自動偵測變數的型別, 而不像 C, 你必須事先宣告
#
# 在 C 中
# ```C
# int main(void) {
#     int i = 0;
#     char x[12] = "Hello world";
#     return(0)
# }
# ```
#
# 在 Python 中
# ```Python
# i = 0
# x = "Hello world"
# ```
#
# Python 本身知道數值與字串的差別
#
# 舉例來說, `+` 對於數字和字串會有不同的作用

# %%
print(3.0 + 1.5)
print("3.0" + "1.5")
print(3.0 + "1.5")
# Out:
# 4.5
# 3.01.5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-38db4693068f> in <module>()
#       1 print(3.0 + 1.5)
#       2 print("3.0" + "1.5")
# ----> 3 print(3.0 + "1.5")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# 在 `+` 的方面, 數字與字串無法混用
#
# 如果你想知道你的變數目前是什麼型別, 你可以用 function `type()`

# %%
xx = 1
print(type(xx))
temp = 98.6
print(type(temp))
print(type(1))
print(type(1.0))
print(type("1.0"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 型別之間有點彈性, 所以其實是可以作轉換的

# %%
print(3 * 2)
print(float(3) * 2)
i = 42
print(type(i))
f = float(i)
print(f)
print(type(f))
print(1 + 2 * float(3) / 4 - 2.5)
# Out:
# 6
# 6.0
# <class 'int'>
# 42.0
# <class 'float'>
# 0.0

# %% [markdown]
# 所以如果你想把數值變數跟字串變數用 `+` 連接起來, 也不是辦不到
#
# 只是你必須先將數值變數轉為字串型別

# %%
"There are " + str(24) + "hour in one day."
# Out:
# 'There are 24hour in one day.'

# %% [markdown]
# 字串變數也能轉成數值變數, 不過你得注意字串變數的內容是否都為數字

# %%
sval = "123"
print( int(sval) * 2)

sval = "123.1"
print( float(sval) * 2) 
print( int(sval) * 2) # 錯誤的轉變型態

nsval = "123y"    # 包含非數值的內容
nsval = "123.1.1" # 錯誤的格式
print( int(nsval) * 2)
# Out:
# 246
# 246.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-67019247b770> in <module>()
#       4 sval = "123.1"
#       5 print( float(sval) * 2)
# ----> 6 print( int(sval) * 2) # 錯誤的轉變型態
#       7
#       8 nsval = "123y"    # 包含非數值的內容
#
# ValueError: invalid literal for int() with base 10: '123.1'

# %% [markdown]
# <a href="user_input"></a>
# ### 使用者輸入 User input
#
# 如果你想要從使用者手中讀取一個數字, 我們變需要 `input` 函式來為我們讀取使用者輸入的**字串**, 再將字串轉成數字型態
#
# 之後我們會提到如何對使用者輸入的資訊做防呆保護, 以免獲得的資訊並不是我們想要的

# %%
inp = input('Europe floor?')
usf = int(inp) + 1
print('US floor', usf)
# Out:
# Europe floor?12
# US floor 13

# %% [markdown]
# <a href="comments"></a>
# ### 註解 Comments
#
# 在 Python 程式碼中, 只要在 `#` 後面的都是註解
#
# ```python
# # Comment one
# print("Hello world") # Comment two
# # print("No show) Comment three
# ```
#
# 插入註解很重要, 當你與其他人共同開發程式, 甚至是自己維護一個小專案時
#
# 你總需要了解別人的想法（或是過去的自己那神奇的想法）
#
# 在程式碼中插入適當的註解, 告訴別人這段程式碼存在的意義也是一件很有意義的事情唷
#
# 除了在說明程式碼的存在意義以外, 也可以拿來暫時關閉某段程式碼, 方便我們除錯 debug
#
# 以下是一段程式碼, 雖然 for, if 的語法還沒告訴你們,
#
# 但你們仍然可以透過註解來了解部分程式碼執行的目的.

# %%
 # Get the name of the file and open it
name = input('Enter file:')
handle = open(name, 'r')
text = handle.read()
words = text.split()

# Count word frequency
counts = dict()
for word in words:
   counts[word] = counts.get(word,0) + 1

# Find the most common word
bigcount = None
bigword = None
for word,count in counts.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count
        
# All done
print(bigword, bigcount)

# %% [markdown]
# <a href="string_operations"></a>
# ### 字串運算 String operations
#
# 有些在運算元 operators 能夠應用到字串上, 如
#
# * `+` 用來連接字串
# * `*` 用來重複字串

# %%
print("Jup" + "yter" + " note" + "book")
print("今年幾倍 "*5)
# Out:
# Jupyter notebook
# 今年幾倍 今年幾倍 今年幾倍 今年幾倍 今年幾倍

# %% [markdown]
# <a href="variable_names"></a>
# ### 變數名稱 Variable names
#
# 身為程式設計師, 我們要為我們的程式碼負責, 變數名稱也是其中一個重要的要項
#
# 幫每個變數找到最適切的名字變成我們的工作, 在很多時候, 程式設計師總帶著英文詞典
#
# 試著幫你的變數找一個好記憶, 富涵義的名稱很重要
#
# 思考以下例子
#
# Example 1.
# ```python
# x1q3z9ocd = 35.0
# x1q3z9afd = 12.50
# x1q3p9afd = x1q3z9ocd * x1q3z9afd
# print x1q3p9afd
# ```
#
# 你覺得例子1看起來如何？順眼嗎？你能否從程式碼知道例子1在做什麼**有意義**的事情？
#
# 再思考以下例子
#
# Example 2.
# ```python
# a = 35.0
# b = 12.50
# c = a * b
# print c
# ```
#
# 看起來順眼多了, 不過變數 a, b, c 有它個別的涵義嗎？
#
# 再看看最後這個例子
#
# Example 3.
# ```python
# hours = 35.0
# rate = 12.50
# pay = hours * rate
# print pay
# ```
#
# 看到例子3, 你終於參透這段程式碼是在計算慣老闆有沒有給滿員工 22k 薪水了
#
# 一切都因為變數名稱而明朗起來, 這就是**取適當變數名稱**的魔力
#
# 現在交給你了, 請好好控制它！

# %% [markdown]
# ## 練習
#
# 請開啟一份新的 python 筆記檔案, 檔名為你的學號, 寫完上傳至網大.
#
# Question:
# ```
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
#
# Example output:
# ```
# Enter Hours: 35
# Enter Rate: 2
# Pay: 96.25
# ```
